# %% [markdown]
# <a href="https://colab.research.google.com/github/SouvikChakraborty472/Web_Scraping/blob/main/Assignment_Module_2_Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Exploring Data Science Job Opportunities 🔍🚀**
#
# Your mission is to design a specialized tool that extracts and analyzes data science job listings from a single online source of your choice. Focus on crafting a laser-focused web scraping solution tailored to the chosen platform, ensuring the collection of crucial details such as job titles, company names, experience requirements, salary ranges, and locations.
#
# ### **Key Tasks:**
#
# 1. **Source Selection:**
# Choose a preferred online platform for data science job listings. Platforms like TimesJobs, LinkedIn Jobs, Indeed, Naukri, Glassdoor are potential options. Specify your chosen source in your solution. 🎯
# 2. **Web Scraping Precision:**
# Engineer a targeted web scraping mechanism adept at extracting specific information from the chosen platform. ⚙️
# 3. **Data Extraction:**
# Focus on extracting essential details from job listings, including but not limited to job titles, company names, required experience levels, salary ranges, and locations. 📊
# 4. **Data Organization:**
# Ensure efficient organization and cleaning of the extracted data. The emphasis should be on presenting the information in a clear and understandable format.🧹
# 5. **Insights Generation:**
# Develop tools for analyzing the gathered data to generate insights. Explore patterns related to job titles, experience requirements, salary distributions, and geographic preferences. 🔍
# 6. **Visualization:**
# Create visual representations such as charts and graphs to communicate the insights effectively. Your visuals should provide a user-friendly interpretation of the data. 📈

# %% [markdown]
# #Web Scraping

# %%
import csv
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# %%
def get_record(card):
    atag = card.h2.a
    job_title = card.find("a").text.strip()
    job_url = 'https://www.timesjobs.com' + atag.get('href')
    company = card.find('h3', 'joblist-comp-name').text.strip().split('\r')[0]
    job_location = card.find('ul').text.strip().split('\n')[-1]
    salary = card.find('ul').text.strip().split('\n')[1]
    experience = card.find('li').text.strip().split('card_travel')[-1]

    record = (job_title,company,job_location,experience,salary,job_url)

    return record

# %%
url = "https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=as&searchTextText=%22Data+Scientist%22&txtKeywords=%22Data+Scientist%22&txtLocation="
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
cards = soup.find_all('li', 'clearfix job-bx wht-shd-bx')
card = cards[0]

# %%
records = []
for card in cards:
    record = get_record(card)
    records.append(record)

# %% [markdown]
# #Data Extraction

# %%
with open('result.csv', 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(['JobTitle', 'Company', 'Location', 'Experience', 'Salary', 'URL'])
        writer.writerows(records)

# %% [markdown]
# #Data Organization

# %%
data = pd.read_csv("/content/result.csv")
data.head()
# Out:
#            JobTitle                                            Company  \
# 0    Data Scientist  Phoenix Global Resettlement Services Pvt Ltd\n...
# 1    Data Scientist  SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 2    Data Scientist  SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 3    Data Scientist  SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 4  Data Scientist ,  SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
#
#                 Location  Experience                       Salary  \
# 0  Bengaluru / Bangalore   3 - 8 yrs                          NaN
# 1              Singapore   2 - 7 yrs  ₹Rs 43.10 - 62.10 Lacs p.a.
# 2     France,  Hong Kong  6 - 11 yrs  ₹Rs 43.10 - 62.10 Lacs p.a.
# 3       Canada,  Germany   2 - 7 yrs  ₹Rs 55.10 - 86.10 Lacs p.a.
# 4                Germany  6 - 11 yrs  ₹Rs 43.10 - 62.10 Lacs p.a.
#
#                                                  URL
# 0  https://www.timesjobs.comhttps://www.timesjobs...
# 1  https://www.timesjobs.comhttps://www.timesjobs...
# 2  https://www.timesjobs.comhttps://www.timesjobs...
# 3  https://www.timesjobs.comhttps://www.timesjobs...
# 4  https://www.timesjobs.comhttps://www.timesjobs...

# %%
data.columns
# Out:
# Index(['JobTitle', 'Company', 'Location', 'Experience', 'Salary', 'URL'], dtype='object')

# %%
data.isnull().sum()
# Out:
# JobTitle       0
# Company        0
# Location       0
# Experience     0
# Salary        20
# URL            0
# dtype: int64

# %%
data.fillna('Not Mentioned')
# Out:
#                                    JobTitle  \
# 0                            Data Scientist
# 1                            Data Scientist
# 2                            Data Scientist
# 3                            Data Scientist
# 4                          Data Scientist ,
# 5                            Data Scientist
# 6   Data Scientist  /  Data Analyst Fresher
# 7                            Data Scientist
# 8                            Data scientist
# 9                            Data Scientist
# 10                           Data Scientist
# 11                           Data Scientist
# 12                           Data Scientist
# 13                           Data Scientist
# 14                           Data Scientist
# 15                           Data Scientist
# 16                           DATA SCIENTIST
# 17                           Data Scientist
# 18                           Data Scientist
# 19                           Data Scientist
# 20                           Data Scientist
# 21                           Data Scientist
# 22                           Data Scientist
# 23                           Data Scientist
# 24                           Data Scientist
#
#                                               Company  \
# 0   Phoenix Global Resettlement Services Pvt Ltd\n...
# 1   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 2   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 3   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 4   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 5          2COMS Consulting Pvt Ltd\n     (More Jobs)
# 6                        Alpha Tech\n     (More Jobs)
# 7                                            RedLotus
# 8                                 HyreFox Consultants
# 9                                  Datagrid Solutions
# 10          Armaco Chemical Processes Systems Pvt Ltd
# 11                                BizViz Technologies
# 12                         Efftronics Systems Pvt Ltd
# 13               axmiyan hr solutions private limited
# 14                   Exxonmobil Company India Pvt Ltd
# 15                        alliance recruitment agency
# 16                                string bio pvt. ltd
# 17                          LogicPlum Private Limited
# 18                          LogicPlum Private Limited
# 19                          LogicPlum Private Limited
# 20                          LogicPlum Private Limited
# 21                          LogicPlum Private Limited
# 22                          LogicPlum Private Limited
# 23                          LogicPlum Private Limited
# 24                 ispatial techno solutions pvt ltd.
#
#                                              Location  Experience  \
# 0                               Bengaluru / Bangalore   3 - 8 yrs
# 1                                           Singapore   2 - 7 yrs
# 2                                  France,  Hong Kong  6 - 11 yrs
# 3                                    Canada,  Germany   2 - 7 yrs
# 4                                             Germany  6 - 11 yrs
# 5                               Bengaluru / Bangalore   4 - 6 yrs
# 6   Bengaluru / Bangalore,  Chennai,  Hyderabad/Se...   0 - 1 yrs
# 7                                              Mumbai   0 - 3 yrs
# 8                                              Jaipur   0 - 3 yrs
# 9                                              Mumbai   5 - 6 yrs
# 10                                        location_on   5 - 8 yrs
# 11     Hyderabad/Secunderabad,  Bengaluru / Bangalore   3 - 6 yrs
# 12                                         Vijayawada   5 - 8 yrs
# 13                                            Gurgaon   3 - 6 yrs
# 5                            Data Scientist
# 6   Data Scientist  /  Data Analyst Fresher
# 7                            Data Scientist
# 8                            Data scientist
# 9                            Data Scientist
# 10                           Data Scientist
# 11                           Data Scientist
# 12                           Data Scientist
# 13                           Data Scientist
# 14                           Data Scientist
# 15                           Data Scientist
# 16                           DATA SCIENTIST
# 17                           Data Scientist
# 18                           Data Scientist
# 19                           Data Scientist
# 20                           Data Scientist
# 21                           Data Scientist
# 22                           Data Scientist
# 23                           Data Scientist
# 24                           Data Scientist
#
#                                               Company  \
# 0   Phoenix Global Resettlement Services Pvt Ltd\n...
# 1   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 2   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 3   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 4   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 5          2COMS Consulting Pvt Ltd\n     (More Jobs)
# 6                        Alpha Tech\n     (More Jobs)
# 7                                            RedLotus
# 8                                 HyreFox Consultants
# 9                                  Datagrid Solutions
# 10          Armaco Chemical Processes Systems Pvt Ltd
# 11                                BizViz Technologies
# 12                         Efftronics Systems Pvt Ltd
# 13               axmiyan hr solutions private limited
# 14                   Exxonmobil Company India Pvt Ltd
# 15                        alliance recruitment agency
# 16                                string bio pvt. ltd
# 17                          LogicPlum Private Limited
# 18                          LogicPlum Private Limited
# 19                          LogicPlum Private Limited
# 20                          LogicPlum Private Limited
# 21                          LogicPlum Private Limited
# 22                          LogicPlum Private Limited
# 23                          LogicPlum Private Limited
# 24                 ispatial techno solutions pvt ltd.
#
#                                              Location  Experience  \
# 0                               Bengaluru / Bangalore   3 - 8 yrs
# 1                                           Singapore   2 - 7 yrs
# 2                                  France,  Hong Kong  6 - 11 yrs
# 3                                    Canada,  Germany   2 - 7 yrs
# 4                                             Germany  6 - 11 yrs
# 5                               Bengaluru / Bangalore   4 - 6 yrs
# 6   Bengaluru / Bangalore,  Chennai,  Hyderabad/Se...   0 - 1 yrs
# 7                                              Mumbai   0 - 3 yrs
# 8                                              Jaipur   0 - 3 yrs
# 9                                              Mumbai   5 - 6 yrs
# 10                                        location_on   5 - 8 yrs
# 11     Hyderabad/Secunderabad,  Bengaluru / Bangalore   3 - 6 yrs
# 12                                         Vijayawada   5 - 8 yrs
# 13                                            Gurgaon   3 - 6 yrs
# 14                              Bengaluru / Bangalore   3 - 6 yrs
# 15                                Noida/Greater Noida   3 - 4 yrs
# 16                              Bengaluru / Bangalore   2 - 5 yrs
# 17                                        location_on   4 - 7 yrs
# 18                                        location_on   4 - 7 yrs
# 19                                        location_on   4 - 7 yrs
# 20                                             Canada   4 - 7 yrs
# 21                                             France   4 - 7 yrs
# 22                                        location_on   4 - 7 yrs
# 23                                        location_on   4 - 7 yrs
# 24                             Hyderabad/Secunderabad  7 - 10 yrs
#
#                          Salary  \
# 0                           NaN
# 1   ₹Rs 43.10 - 62.10 Lacs p.a.
# 2   ₹Rs 43.10 - 62.10 Lacs p.a.
# 3   ₹Rs 55.10 - 86.10 Lacs p.a.
# 4   ₹Rs 43.10 - 62.10 Lacs p.a.
# 5                           NaN
# 6     ₹Rs 4.50 - 7.50 Lacs p.a.
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
#
#                                                   URL min_exp max_exp
# 0   https://www.timesjobs.comhttps://www.timesjobs...       3       8
# 1   https://www.timesjobs.comhttps://www.timesjobs...       2       7
# 2   https://www.timesjobs.comhttps://www.timesjobs...       6       1
# 3   https://www.timesjobs.comhttps://www.timesjobs...       2       7
# 4   https://www.timesjobs.comhttps://www.timesjobs...       6       1
# 5   https://www.timesjobs.comhttps://www.timesjobs...       4       6
# 6   https://www.timesjobs.comhttps://www.timesjobs...       0       1
# 7   https://www.timesjobs.comhttps://www.timesjobs...       0       3
# 8   https://www.timesjobs.comhttps://www.timesjobs...       0       3
# 9   https://www.timesjobs.comhttps://www.timesjobs...       5       6
# 10  https://www.timesjobs.comhttps://www.timesjobs...       5       8
# 11  https://www.timesjobs.comhttps://www.timesjobs...       3       6
# 12  https://www.timesjobs.comhttps://www.timesjobs...       5       8
# 13  https://www.timesjobs.comhttps://www.timesjobs...       3       6
# 14  https://www.timesjobs.comhttps://www.timesjobs...       3       6
# 15  https://www.timesjobs.comhttps://www.timesjobs...       3       4
# 16  https://www.timesjobs.comhttps://www.timesjobs...       2       5
# 17  https://www.timesjobs.comhttps://www.timesjobs...       4       7
# 18  https://www.timesjobs.comhttps://www.timesjobs...       4       7
# 19  https://www.timesjobs.comhttps://www.timesjobs...       4       7
# 20  https://www.timesjobs.comhttps://www.timesjobs...       4       7
# 21  https://www.timesjobs.comhttps://www.timesjobs...       4       7
# 22  https://www.timesjobs.comhttps://www.timesjobs...       4       7
# 23  https://www.timesjobs.comhttps://www.timesjobs...       4       7
# 24  https://www.timesjobs.comhttps://www.timesjobs...       7       1

# %%
data.loc[data["Location"] == "location_on", "Location"] = "not_mentioned"
data
# Out:
#                                    JobTitle  \
# 0                            Data Scientist
# 1                            Data Scientist
# 2                            Data Scientist
# 3                            Data Scientist
# 4                          Data Scientist ,
# 5                            Data Scientist
# 6   Data Scientist  /  Data Analyst Fresher
# 7                            Data Scientist
# 8                            Data scientist
# 9                            Data Scientist
# 10                           Data Scientist
# 11                           Data Scientist
# 12                           Data Scientist
# 13                           Data Scientist
# 14                           Data Scientist
# 15                           Data Scientist
# 16                           DATA SCIENTIST
# 17                           Data Scientist
# 18                           Data Scientist
# 19                           Data Scientist
# 20                           Data Scientist
# 21                           Data Scientist
# 22                           Data Scientist
# 23                           Data Scientist
# 24                           Data Scientist
#
#                                               Company  \
# 0   Phoenix Global Resettlement Services Pvt Ltd\n...
# 1   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 2   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 3   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 4   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 5          2COMS Consulting Pvt Ltd\n     (More Jobs)
# 6                        Alpha Tech\n     (More Jobs)
# 7                                            RedLotus
# 8                                 HyreFox Consultants
# 9                                  Datagrid Solutions
# 10          Armaco Chemical Processes Systems Pvt Ltd
# 11                                BizViz Technologies
# 12                         Efftronics Systems Pvt Ltd
# 13               axmiyan hr solutions private limited
# 14                   Exxonmobil Company India Pvt Ltd
# 15                        alliance recruitment agency
# 16                                string bio pvt. ltd
# 17                          LogicPlum Private Limited
# 18                          LogicPlum Private Limited
# 19                          LogicPlum Private Limited
# 20                          LogicPlum Private Limited
# 21                          LogicPlum Private Limited
# 22                          LogicPlum Private Limited
# 23                          LogicPlum Private Limited
# 24                 ispatial techno solutions pvt ltd.
#
#                                              Location  Experience  \
# 0                               Bengaluru / Bangalore   3 - 8 yrs
https://www.timesjobs.comhttps://www.timesjobs...       4       7
# 24  https://www.timesjobs.comhttps://www.timesjobs...       7       1

# %%
data['initial_salary'] = data.Salary.str[:9]

# %%
data
# Out:
#                                    JobTitle  \
# 0                            Data Scientist
# 1                            Data Scientist
# 2                            Data Scientist
# 3                            Data Scientist
# 4                          Data Scientist ,
# 5                            Data Scientist
# 6   Data Scientist  /  Data Analyst Fresher
# 7                            Data Scientist
# 8                            Data scientist
# 9                            Data Scientist
# 10                           Data Scientist
# 11                           Data Scientist
# 12                           Data Scientist
# 13                           Data Scientist
# 14                           Data Scientist
# 15                           Data Scientist
# 16                           DATA SCIENTIST
# 17                           Data Scientist
# 18                           Data Scientist
# 19                           Data Scientist
# 20                           Data Scientist
# 21                           Data Scientist
# 22                           Data Scientist
# 23                           Data Scientist
# 24                           Data Scientist
#
#                                               Company  \
# 0   Phoenix Global Resettlement Services Pvt Ltd\n...
# 1   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 2   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 3   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 4   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 5          2COMS Consulting Pvt Ltd\n     (More Jobs)
# 6                        Alpha Tech\n     (More Jobs)
# 7                                            RedLotus
# 8                                 HyreFox Consultants
# 9                                  Datagrid Solutions
# 10          Armaco Chemical Processes Systems Pvt Ltd
# 11                                BizViz Technologies
# 12                         Efftronics Systems Pvt Ltd
# 13               axmiyan hr solutions private limited
# 14                   Exxonmobil Company India Pvt Ltd
# 15                        alliance recruitment agency
# 16                                string bio pvt. ltd
# 17                          LogicPlum Private Limited
# 18                          LogicPlum Private Limited
# 19                          LogicPlum Private Limited
# 20                          LogicPlum Private Limited
# 21                          LogicPlum Private Limited
# 22                          LogicPlum Private Limited
# 23                          LogicPlum Private Limited
# 24                 ispatial techno solutions pvt ltd.
#
#                                              Location  Experience  \
# 0                               Bengaluru / Bangalore   3 - 8 yrs
# 1                                           Singapore   2 - 7 yrs
# 2                                  France,  Hong Kong  6 - 11 yrs
# 3                                    Canada,  Germany   2 - 7 yrs
# 4                                             Germany  6 - 11 yrs
# 5                               Bengaluru / Bangalore   4 - 6 yrs
# 6   Bengaluru / Bangalore,  Chennai,  Hyderabad/Se...   0 - 1 yrs
# 7                                              Mumbai   0 - 3 yrs
# 8                                              Jaipur   0 - 3 yrs
# 9                                              Mumbai   5 - 6 yrs
# 10                                      not_mentioned   5 - 8 yrs
# 11     Hyderabad/Secunderabad,  Bengaluru / Bangalore   3 - 6 yrs
# 12                                         Vijayawada   5 - 8 yrs
# 13                                            Gurgaon   3 - 6 yrs
# 14                              Bengaluru / Bangalore   3 - 6 yrs
# 15                                Noida/Greater Noida   3 - 4 yrs
# 16                              Bengaluru / Bangalore   2 - 5 yrs
# 17                                      not_mentioned   4 - 7 yrs
# 18                                      not_mentioned   4 - 7 yrs
# 19                                      not_mentioned   4 - 7 yrs
# 20                                             Canada   4 - 7 yrs
# 21                                             France   4 - 7 yrs
# 22                                      not_mentioned   4 - 7 yrs
# 23                                      not_mentioned   4 - 7 yrs
# 24                             Hyderabad/Secunderabad  7 - 10 yrs
#
#                          Salary  \
# 0                           NaN
# 1   ₹Rs 43.10 - 62.10 Lacs p.a.
# 2   ₹Rs 43.10 - 62.10 Lacs p.a.
# 3   ₹Rs 55.10 - 86.10 Lacs p.a.
# 4   ₹Rs 43.10 - 62.10 Lacs p.a.
# 5                           NaN
# 6     ₹Rs 4.50 - 7.50 Lacs p.a.
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
#
#                                                   URL min_exp max_exp  \
# 0   https://www.timesjobs.comhttps://www.timesjobs...       3       8
# 1   https://www.timesjobs.comhttps://www.timesjobs...       2       7
# 2   https://www.timesjobs.comhttps://www.timesjobs...       6       1
# 3   https://www.timesjobs.comhttps://www.timesjobs...       2       7
# 4   https://www.timesjobs.comhttps://www.timesjobs...       6       1
# 5   https://www.timesjobs.comhttps://www.timesjobs...       4       6
# 6   https://www.timesjobs.comhttps://www.timesjobs...       0       1
# 7   https://www.timesjobs.comhttps://www.timesjobs...       0       3
# 8   https://www.timesjobs.comhttps://www.timesjobs...       0       3
# 9   https://www.timesjobs.comhttps://www.timesjobs...       5       6
# 10  https://www.timesjobs.comhttps://www.timesjobs...       5       8
# 11  https://www.timesjobs.comhttps://www.timesjobs...       3       6
# 12  https://www.timesjobs.comhttps://www.timesjobs...       5       8
# 13  https://www.timesjobs.comhttps://www.timesjobs...       3       6
# 14  https://www.timesjobs.comhttps://www.timesjobs...       3       6
# 15  https://www.timesjobs.comhttps://www.timesjobs...       3       4
# 16  https://www.timesjobs.comhttps://www.timesjobs...       2       5
# 17  https://www.timesjobs.comhttps://www.timesjobs...       4       7
# 18  https://www.timesjobs.comhttps://www.timesjobs...       4       7
# 19  https://www.timesjobs.comhttps://www.timesjobs...       4       7
# 20  https://www.timesjobs.comhttps://www.timesjobs...       4       7
# 21  https://www.timesjobs.comhttps://www.timesjobs...       4       7
# 22  https://www.timesjobs.comhttps://www.timesjobs...       4       7
# 23  https://www.timesjobs.comhttps://www.timesjobs...       4       7
# 24  https://www.timesjobs.comhttps://www.timesjobs...       7       1
#
#    initial_salary
# 0             NaN
# 1       ₹Rs 43.10
# 2       ₹Rs 43.10
# 3       ₹Rs 55.10
# 4       ₹Rs 43.10
# 5             NaN
# 6       ₹Rs 4.50
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN

# %%
data = data.drop(columns = ['JobTitle', 'Experience', 'Salary', 'URL'])

# %%
data
# Out:
#                                               Company  \
# 0   Phoenix Global Resettlement Services Pvt Ltd\n...
# 1   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 2   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 3   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 4   SKYWALK VISA IMMIGRATION SERVICES LLP\n     (M...
# 5          2COMS Consulting Pvt Ltd\n     (More Jobs)
# 6                        Alpha Tech\n     (More Jobs)
# 7                                            RedLotus
# 8                                 HyreFox Consultants
# 9                                  Datagrid Solutions
# 10          Armaco Chemical Processes Systems Pvt Ltd
# 11                                BizViz Technologies
# 12                         Efftronics Systems Pvt Ltd
# 13               axmiyan hr solutions private limited
# 14                   Exxonmobil Company India Pvt Ltd
# 15                        alliance recruitment agency
# 16                                string bio pvt. ltd
# 17                          LogicPlum Private Limited
# 18                          LogicPlum Private Limited
# 19                          LogicPlum Private Limited
# 20                          LogicPlum Private Limited
# 21                          LogicPlum Private Limited
# 22                          LogicPlum Private Limited
# 23                          LogicPlum Private Limited
# 24                 ispatial techno solutions pvt ltd.
#
#                                              Location min_exp max_exp  \
# 0                               Bengaluru / Bangalore       3       8
# 1                                           Singapore       2       7
# 2                                  France,  Hong Kong       6       1
# 3                                    Canada,  Germany       2       7
# 4                                             Germany       6       1
# 5                               Bengaluru / Bangalore       4       6
# 6   Bengaluru / Bangalore,  Chennai,  Hyderabad/Se...       0       1
# 7                                              Mumbai       0       3
# 8                                              Jaipur       0       3
# 9                                              Mumbai       5       6
# 10                                      not_mentioned       5       8
# 11     Hyderabad/Secunderabad,  Bengaluru / Bangalore       3       6
# 12                                         Vijayawada       5       8
# 13                                            Gurgaon       3       6
# 14                              Bengaluru / Bangalore       3       6
# 15                                Noida/Greater Noida       3       4
# 16                              Bengaluru / Bangalore       2       5
# 17                                      not_mentioned       4       7
# 18                                      not_mentioned       4       7
# 19                                      not_mentioned       4       7
# 20                                             Canada       4       7
# 21                                             France       4       7
# 22                                      not_mentioned       4       7
# 23                                      not_mentioned       4       7
# 24                             Hyderabad/Secunderabad       7       1
#
#    initial_salary
# 0             NaN
# 1       ₹Rs 43.10
# 2       ₹Rs 43.10
# 3       ₹Rs 55.10
# 4       ₹Rs 43.10
# 5             NaN
# 6       ₹Rs 4.50
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN

# %% [markdown]
# #Insights Generation

# %%
company_count = data['Company'].nunique()
print(f'The number of unique companies is: {company_count}')
# Out:
# The number of unique companies is: 16

# %%
unique_companies = data['Company'].unique()
for company in unique_companies:
    print(company)
# Out:
# Phoenix Global Resettlement Services Pvt Ltd
#      (More Jobs)
# SKYWALK VISA IMMIGRATION SERVICES LLP
#      (More Jobs)
# 2COMS Consulting Pvt Ltd
#      (More Jobs)
# Alpha Tech
#      (More Jobs)
# RedLotus
# HyreFox Consultants
# Datagrid Solutions
# Armaco Chemical Processes Systems Pvt Ltd
# BizViz Technologies
# Efftronics Systems Pvt Ltd
# axmiyan hr solutions private limited
# Exxonmobil Company India Pvt Ltd
# alliance recruitment agency
# string bio pvt. ltd
# LogicPlum Private Limited
# ispatial techno solutions pvt ltd.

# %%
Max_company = data['Company'].value_counts().idxmax()
print(f'The company that appears the most: {Max_company}')
# Out:
# The company that appears the most: LogicPlum Private Limited

# %%
mumbai_recruiters = data[data['Location'] == 'Mumbai']
print(mumbai_recruiters['Company'])
# Out:
# 7              RedLotus
# 9    Datagrid Solutions
# Name: Company, dtype: object

# %%
job_fresher = data[data['min_exp'] == '0' ]
company_fresher = job_fresher['Company']
print(f'Companies recruiting freshers are: {company_fresher}')
# Out:
# Companies recruiting freshers are: 6    Alpha Tech\n     (More Jobs)
# 7                        RedLotus
# 8             HyreFox Consultants
# Name: Company, dtype: object

# %% [markdown]
# #Visualization

# %%
company_counts = data['Company'].value_counts()
company_counts.plot(kind = 'bar', color = 'skyblue', edgecolor = 'black')
plt.xlabel('Company')
plt.ylabel('Count')
plt.title('Unique Company Counts')
# Out:
# Text(0.5, 1.0, 'Unique Company Counts')

# %%
minexp_counts = data.groupby('min_exp')['Company'].nunique()
plt.pie(minexp_counts, labels=minexp_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Company Counts by minimum experience')
plt.axis('equal')
plt.show()
